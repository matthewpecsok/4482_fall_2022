# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewpecsok/4482_fall_2022/blob/main/labs/Preparation_for_Data_Mining_with_Python_in_Colab_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4482 - Lab1 Preparation for Data Mining with Python in Colab
#
# Authors: Olivia Sheng and Matthew Pecsok

# %% [markdown]
# ### Your first Colab notebook
#
# ####
#
# Change this text to your name first Colab notebook. For example
# Matthew Pecsok first Colab Notebook
# #####

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#### Your hello world goes here
### Your code begin

### Your code end

# %% [markdown]
# Create a new code block:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)!

# %% [markdown]
# In your new code block add 1+1 and run the cell. Your output should be 2.

# %% [markdown]
# To create a new TEXT just hover your mouse in the middle of the block you want to add a new block above or below. If you get your cursor in the right spot the follow option will appear. Click the + button to add a new Text block. And add the wordss "Hi I'm just text, I'm not code."

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can now type text directly into this block. It will NOT be interpreted as code and will simply print out what you type. You may use heading indicators such as # ## ### to indicate different heading levels.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Importing a csv file into a pandas dataframe.
#
# With the mounted drive you can now reference the csv file you have uploaded. Run the following code to import the csv file as a pandas dataframe.

# %%
# import file into pandas dataframe
import pandas as pd

carAuction = pd.read_csv("https://raw.githubusercontent.com/matthewpecsok/4482_fall_2022/main/data/carAuction.csv")

# %% [markdown]
# List the contents of the file by showing the first 5 rows. One thing to notice is that there is a row 0. Python has most objects as zero based meaning counting starts at 0 not 1. This is different from R as it is 1 based and is critical to remember as you begin your assignments.

# %%
carAuction.head(12)
# Out:
#    Auction   Color IsBadBuy  MMRCurrentAuctionAveragePrice         Size  \
# 0    ADESA   WHITE       No                           2871  LARGE TRUCK
# 1    ADESA    GOLD      Yes                           1840          VAN
# 2    ADESA     RED       No                           8931    SMALL SUV
# 3    ADESA    GOLD       No                           8320    CROSSOVER
# 4    ADESA    GREY       No                          11520  LARGE TRUCK
# 5    ADESA  SILVER       No                           2659      COMPACT
# 6    ADESA     RED       No                           4645          VAN
# 7    ADESA  SILVER       No                           4352        LARGE
# 8    ADESA  SILVER       No                           5142       MEDIUM
# 9    ADESA  MAROON       No                           9983       MEDIUM
# 10   ADESA   WHITE       No                           4165       MEDIUM
# 11   ADESA    GOLD       No                           2422          VAN
#
# ...

# %%
# the df.tail() command allows you to see the last n number of rows (5 by default). Use the tail command to show the default 5 last rows. Do not type 5, let the
# command default the value. 
### your code begins


### your code ends

# %%
### show the last 12 rows in the dataframe using the tail command
### your code begins


### your code ends

# %% [markdown]
# ### Make a graph of our dataset
#
# Now that we have a dataset imported let's do a quick plot to visualize the dataset.

# %%
# plot the scores from the grid search cv results
import matplotlib.pyplot as plt
#plt.figure()

plt.scatter(carAuction['VehOdo'],carAuction['MMRCurrentAuctionAveragePrice'])
plt.xlabel('mileage (in miles)')
plt.ylabel('auction cost (in dollars)')
plt.title('vehicle cost by mileage')
plt.show()

# %%
### plot warrant cost by mileage
### make sure to change your plot labels and title!
### your code begins


### your code ends

# %% [markdown]
# ### Exporting your work
#
# Finally we need to prove we can export the Colab as a pdf and download the ipynb. This is basically the same thing as making a html document of your Rmd and then submitting both a Rmd and an html. In this class you may end up submitting an html and a .ipynb file.

# %% [markdown]
# ### Authorizing Colab to access your Google Drive

# %% [markdown]
# In order to gain access to the csv file that you have uploaded you must  authorize the Colab to access your google drive folder. Run the following code block and click the link that you are prompted to click. Once you go to the website you can copy the authorization code and paste into the space provided. Click "Allow". This process is important as it must be done EACH time your session expires. So each time you work on assignment you will need to reauthorize Colab to access your google drive folder.

# %%
# Insert a code cell to include to following line of command in each  
# Colab notebook to access data files saved in Google Drive of your account
# Retrieve csv file from google drive by mapping the folder from google drive. 
# Must be done each time session expires.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Copy the access code by clicking the "copy" button.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now you can paste the authorization code into the space provided in the colab block.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Successfully connected!
#
# ![image.png](data:image/png;base64,...)

# %%
# copy the ipynb to the local working directory
# This file name must change to be the name of your Lab file!
# !cp "/content/drive/My Drive/Colab Notebooks/change_me.ipynb" ./

# create html from ipynb
# !jupyter nbconvert --to html "change_me.ipynb"
# Out:
# [NbConvertApp] Converting notebook Preparation_for_Data_Mining_with_Python_in_Colab.ipynb to html
# [NbConvertApp] Writing 838041 bytes to Preparation_for_Data_Mining_with_Python_in_Colab.html

# %% [markdown]
# Now go to the nav bar on the left, choose the folder icon and you will see the local files in your working directory. If you refresh you should see the html file that has been created

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now you can dowload the html file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Colab Preparation Complete!
#
# Use the downloaded files to complete your lab.
